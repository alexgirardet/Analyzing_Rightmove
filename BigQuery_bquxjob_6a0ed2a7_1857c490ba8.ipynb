# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'ric-eu-dl-ops-dev-nprd' # Project ID inserted based on the query results selected to explore
location = 'EU' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=ric-eu-dl-ops-dev-nprd:EU:bquxjob_6a0ed2a7_1857c490ba8)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_6a0ed2a7_1857c490ba8') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# with full_table as (SELECT
# creation_time,
# project_id,
# user_email,
# job_id,
# job_type,
# statement_type,
# priority,
# start_time,
# state,
# cache_hit,
# error_result.reason,
# total_bytes_processed,
# total_slot_ms,
# destination_table.project_id as destination_table_id,
# total_bytes_billed,
# parent_job_id
#
# FROM `ric-eu-dl-lz-dev-nprd.alexsbx_billing_export.information_schema_source`
# ),
#
# job_stages as (
#   SELECT jb.status as job_status,
#   job_id
#   FROM  `ric-eu-dl-lz-dev-nprd.alexsbx_billing_export.information_schema_source`,
#   UNNEST(job_stages) as jb
# )
#
# SELECT full_table.*, j_s.job_status FROM full_table
# LEFT JOIN job_stages as j_s
# ON full_table.job_id = j_s.job_id

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_6a0ed2a7_1857c490ba8') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
# Warning: total number of rows (16160194) exceeds max_rows (20000). Falling back to pandas display.
#                             creation_time              project_id  \
# 0        2022-10-19 04:20:39.174000+00:00  ric-eu-dl-ops-dev-nprd
# 1        2022-11-25 11:42:09.070000+00:00  ric-eu-dl-ops-dev-nprd
# 2        2022-07-28 04:41:33.114000+00:00  ric-eu-dl-ops-dev-nprd
# 3        2022-07-28 04:41:33.114000+00:00  ric-eu-dl-ops-dev-nprd
# 4        2022-07-15 09:57:56.507000+00:00  ric-eu-dl-ops-dev-nprd
# ...                                   ...                     ...
# 16160189 2022-08-12 08:34:38.610000+00:00  ric-eu-dl-ops-dev-nprd
# 16160190 2022-08-12 08:34:38.610000+00:00  ric-eu-dl-ops-dev-nprd
# 16160191 2022-10-01 12:02:52.542000+00:00  ric-eu-dl-ops-dev-nprd
# 16160192 2022-10-01 12:02:52.542000+00:00  ric-eu-dl-ops-dev-nprd
# 16160193 2022-10-01 12:02:52.542000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                  user_email  \
# 0         sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 1         sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 2         sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 3         sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 4         sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# ...                                                     ...
# 16160189  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16160190  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16160191  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16160192  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16160193  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
#
#                                                      job_id job_type  \
# 0                      36637663-0d77-4766-a4db-5ea28b617e3f    QUERY
# 1                      b0d75035-6743-4093-a1a1-8225a5bd9cb5    QUERY
# 2         airflow_elevate_sbx_incremental_dbt_run_dm_ele...    QUERY
# 3         airflow_elevate_sbx_incremental_dbt_run_dm_ele...    QUERY
# 4                      aeab250a-e5be-422f-8d0e-43d98577d17a    QUERY
# ...                                                     ...      ...
# 16160189               a6ea99de-ef01-4a6d-8411-076cb296427c    QUERY
# 16160190               a6ea99de-ef01-4a6d-8411-076cb296427c    QUERY
# 16160191               f64074bf-657b-4fa3-bbb8-84d164e36193    QUERY
# 16160192               f64074bf-657b-4fa3-bbb8-84d164e36193    QUERY
# 16160193               f64074bf-657b-4fa3-bbb8-84d164e36193    QUERY
#
#                   statement_type     priority  \
# 0                         SELECT  INTERACTIVE
# 1                         SELECT  INTERACTIVE
# 2                         SELECT  INTERACTIVE
# 3                         SELECT  INTERACTIVE
# 4         CREATE_TABLE_AS_SELECT  INTERACTIVE
# ...                          ...          ...
# 16160189                  SELECT  INTERACTIVE
# 16160190                  SELECT  INTERACTIVE
# 16160191                  SELECT  INTERACTIVE
# 16160192                  SELECT  INTERACTIVE
# 16160193                  SELECT  INTERACTIVE
#
#                                start_time state  cache_hit reason  \
# 0        2022-10-19 04:20:39.308000+00:00  DONE      False   None
# 1        2022-11-25 11:42:09.169000+00:00  DONE      False   None
# 2        2022-07-28 04:41:33.297000+00:00  DONE      False   None
# 3        2022-07-28 04:41:33.297000+00:00  DONE      False   None
# 4        2022-07-15 09:57:56.637000+00:00  DONE      False   None
# ...                                   ...   ...        ...    ...
# 16160189 2022-08-12 08:34:38.872000+00:00  DONE      False   None
# 16160190 2022-08-12 08:34:38.872000+00:00  DONE      False   None
# 16160191 2022-10-01 12:02:52.776000+00:00  DONE      False   None
# 16160192 2022-10-01 12:02:52.776000+00:00  DONE      False   None
# 16160193 2022-10-01 12:02:52.776000+00:00  DONE      False   None
#
#           total_bytes_processed  total_slot_ms       destination_table_id  \
# 0                      16189888            657     ric-eu-dl-ops-dev-nprd
# 1                    3213479576         192320     ric-eu-dl-ops-dev-nprd
# 2                      55666783          19184  ric-eu-dl-cl-vca-dev-nprd
# 3                      55666783          19184  ric-eu-dl-cl-vca-dev-nprd
# 4                    2437278461         209780      ric-eu-dl-vc-dev-nprd
# ...                         ...            ...                        ...
# 16160189               20971520          42395     ric-eu-dl-ops-dev-nprd
# 16160190               20971520          42395     ric-eu-dl-ops-dev-nprd
# 16160191               20971520          34759     ric-eu-dl-ops-dev-nprd
# 16160192               20971520          34759     ric-eu-dl-ops-dev-nprd
# 16160193               20971520          34759     ric-eu-dl-ops-dev-nprd
#
#           total_bytes_billed parent_job_id job_status
# 0                   16777216          None   COMPLETE
# 1                 3213885440          None   COMPLETE
# 2                   56623104          None   COMPLETE
# 3                   56623104          None   COMPLETE
# 4                 2437939200          None   COMPLETE
# ...                      ...           ...        ...
# 16160189            31457280          None   COMPLETE
# 16160190            31457280          None   COMPLETE
# 16160191            31457280          None   COMPLETE
# 16160192            31457280          None   COMPLETE
# 16160193            31457280          None   COMPLETE
#
# [16160194 rows x 17 columns]

# %% [markdown]
# # Analyze day

# %%
import pandas as pd

# %%
results['date']  = results['creation_time'].dt.date

# %%
results['date'] = results.date.apply(lambda x: str(x))

# %%
given_day = results[results['date'] == '2022-11-17']

# %%
given_day.parent_job_id.value_counts()
# Out:
# bd2c3cc2-df9c-4a11-a8e1-776f3cee0e7d    2662
# 456da04c-194a-49a6-8533-99389e9c9e7f    2654
# 69542730-56dd-4f19-8eb7-f529220e43e2    2653
# d8183979-ada6-451f-8e06-77c1ca0da31d    2653
# b4953029-d3ba-4f2f-8bef-93e9004ec3d4    2459
#                                         ...
# d17d1214-ceac-4c52-bbbf-caafe6a8b074      10
# 5a5fb263-40c8-4c55-8140-62c7b7c774dd       1
# 7cca345c-53b7-4417-a7c5-3e506d1a4fa5       1
# ffe59bb9-ba41-4898-96d6-cb9d4b0e22c6       1
# 76d6c488-f876-4daf-ac24-deb9983eb23d       1
# Name: parent_job_id, Length: 166, dtype: int64

# %%
bool_series = pd.isnull(given_day["parent_job_id"])

# %%
no_parents = given_day[bool_series].drop_duplicates()

# %%
no_parents_no_cached = no_parents[no_parents['cache_hit'] == False]

# %%
(no_parents_no_cached.total_bytes_billed.sum() *  9.09494702E-13) * 5
# Out:
# 4052.3050842865723

# %%
(no_parents_no_cached.drop_duplicates(subset=['job_id']).total_bytes_billed.sum() *  9.09494702E-13) * 5
# Out:
# 4052.3050842865723

# %%
no_parents_no_cached.project_id.value_counts()
# Out:
# ric-eu-dl-ops-dev-nprd    52601
# Name: project_id, dtype: int64

# %%
no_parents_no_cached
# Out:
# Warning: total number of rows (52601) exceeds max_rows (20000). Falling back to pandas display.
#                             creation_time              project_id  \
# 16       2022-11-17 09:56:24.763000+00:00  ric-eu-dl-ops-dev-nprd
# 304      2022-11-17 22:12:34.312000+00:00  ric-eu-dl-ops-dev-nprd
# 309      2022-11-17 15:35:37.660000+00:00  ric-eu-dl-ops-dev-nprd
# 570      2022-11-17 10:41:06.603000+00:00  ric-eu-dl-ops-dev-nprd
# 643      2022-11-17 11:41:16.551000+00:00  ric-eu-dl-ops-dev-nprd
# ...                                   ...                     ...
# 16070626 2022-11-17 10:48:27.503000+00:00  ric-eu-dl-ops-dev-nprd
# 16073148 2022-11-17 15:57:01.489000+00:00  ric-eu-dl-ops-dev-nprd
# 16082292 2022-11-17 14:14:51.957000+00:00  ric-eu-dl-ops-dev-nprd
# 16091174 2022-11-17 09:09:35.281000+00:00  ric-eu-dl-ops-dev-nprd
# 16091233 2022-11-17 09:52:22.619000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                  user_email  \
# 16        sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 304       sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 309       hvr-agent-cortex@ric-eu-dl-ops-dev-nprd.iam.gs...
# 570       hvr-agent-cortex@ric-eu-dl-ops-dev-nprd.iam.gs...
# 643       hvr-agent-cortex@ric-eu-dl-ops-dev-nprd.iam.gs...
# ...                                                     ...
# 16070626  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16073148  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 16082292  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16091174  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16091233  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
#
#                                         job_id job_type  \
# 16        153c4d5a-5d03-44a4-abc0-f55d2e01a006    QUERY
# 304       edefa64a-d0b9-4c1e-86b1-8df00ba23adb    QUERY
# 309           job_d-Tjo9DVuD-DIJ-2lIQIq4bUE-Wo    QUERY
# 570           job_avmE1brS4sYDJpPADyLuET7wRHzx    QUERY
# 643           job_18VDDXhSe2NVJ5YMiDVlzKZpDs0w    QUERY
# ...                                        ...      ...
# 16070626  5312215e-cb3c-4f0d-a400-6d5521f189e8    QUERY
# 16073148  e43869a9-6436-4c08-8b80-f6db8331b11e    QUERY
# 16082292  5c208ebb-7b6e-4643-8ba1-975df030c85c    QUERY
# 16091174  13c5c764-8069-478b-b187-88b0409538e0    QUERY
# 16091233  d7de8155-428b-48da-9e60-363f7a889984    QUERY
#
#                   statement_type     priority  \
# 16        CREATE_TABLE_AS_SELECT  INTERACTIVE
# 304       CREATE_TABLE_AS_SELECT  INTERACTIVE
# 309                       INSERT  INTERACTIVE
# 570                       INSERT  INTERACTIVE
# 643                       DELETE  INTERACTIVE
# ...                          ...          ...
# 16070626                  SELECT  INTERACTIVE
# 16073148                  SELECT  INTERACTIVE
# 16082292                  SELECT  INTERACTIVE
# 16091174                  SELECT  INTERACTIVE
# 16091233                  SELECT  INTERACTIVE
#
#                                start_time state  cache_hit reason  \
# 16       2022-11-17 09:56:25.015000+00:00  DONE      False   None
# 304      2022-11-17 22:12:34.612000+00:00  DONE      False   None
# 309      2022-11-17 15:35:37.811000+00:00  DONE      False   None
# 570      2022-11-17 10:41:06.758000+00:00  DONE      False   None
# 643      2022-11-17 11:41:16.777000+00:00  DONE      False   None
# ...                                   ...   ...        ...    ...
# 16070626 2022-11-17 10:48:27.690000+00:00  DONE      False   None
# 16073148 2022-11-17 15:57:01.850000+00:00  DONE      False   None
# 16082292 2022-11-17 14:14:52.094000+00:00  DONE      False   None
# 16091174 2022-11-17 09:09:35.429000+00:00  DONE      False   None
# 16091233 2022-11-17 09:52:22.762000+00:00  DONE      False   None
#
#           total_bytes_processed  total_slot_ms       destination_table_id  \
# 16                    227290876          14378  ric-eu-dl-cl-mtb-dev-nprd
# 304                  9043655879         947331      ric-eu-dl-vc-dev-nprd
# 309                   353392755          41203     ric-eu-dl-ops-dev-nprd
# 570                   353641707          54461     ric-eu-dl-ops-dev-nprd
# 643                  6365123609           9027     ric-eu-dl-ops-dev-nprd
# ...                         ...            ...                        ...
# 16070626               20971520          19061     ric-eu-dl-ops-dev-nprd
# 16073148               20971520          21067     ric-eu-dl-ops-dev-nprd
# 16082292               20971520          21485     ric-eu-dl-ops-dev-nprd
# 16091174               20971520          24067     ric-eu-dl-ops-dev-nprd
# 16091233               20971520          21349     ric-eu-dl-ops-dev-nprd
#
#           total_bytes_billed parent_job_id job_status        date
# 16                 227540992          None   COMPLETE  2022-11-17
# 304               9043968000          None   COMPLETE  2022-11-17
# 309                354418688          None   COMPLETE  2022-11-17
# 570                354418688          None   COMPLETE  2022-11-17
# 643               6365904896          None   COMPLETE  2022-11-17
# ...                      ...           ...        ...         ...
# 16070626            31457280          None   COMPLETE  2022-11-17
# 16073148            31457280          None   COMPLETE  2022-11-17
# 16082292            31457280          None   COMPLETE  2022-11-17
# 16091174            31457280          None   COMPLETE  2022-11-17
# 16091233            31457280          None   COMPLETE  2022-11-17
#
# [52601 rows x 18 columns]

# %%
given_day_cached = given_day[given_day['cache_hit'] == True]

# %%
given_day_cached
# Out:
# 8612198     None
# 8614844     None
# 8634864     None
# 8648459     None
# 8671791     None
#             ...
# 11788144    None
# 11799283    None
# 11817434    None
# 11825402    None
# 11878675    None
# Name: parent_job_id, Length: 290, dtype: object

# %%
given_day[given_day['parent_job_id'] == 'd8183979-ada6-451f-8e06-77c1ca0da31d']
# Out:
#                             creation_time              project_id  \
# 31133    2022-11-17 10:39:35.041000+00:00  ric-eu-dl-ops-dev-nprd
# 32183    2022-11-17 10:39:35.041000+00:00  ric-eu-dl-ops-dev-nprd
# 32184    2022-11-17 10:39:35.041000+00:00  ric-eu-dl-ops-dev-nprd
# 32185    2022-11-17 10:39:35.041000+00:00  ric-eu-dl-ops-dev-nprd
# 33244    2022-11-17 10:39:35.041000+00:00  ric-eu-dl-ops-dev-nprd
# ...                                   ...                     ...
# 11529509 2022-11-17 10:26:05.875000+00:00  ric-eu-dl-ops-dev-nprd
# 11663455 2022-11-17 10:57:32.942000+00:00  ric-eu-dl-ops-dev-nprd
# 11753533 2022-11-17 10:26:12.060000+00:00  ric-eu-dl-ops-dev-nprd
# 11756626 2022-11-17 10:26:19.321000+00:00  ric-eu-dl-ops-dev-nprd
# 11809535 2022-11-17 10:26:14.522000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                  user_email  \
# 31133     sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 32183     sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 32184     sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 32185     sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 33244     sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# ...                                                     ...
# 11529509  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 11663455  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 11753533  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 11756626  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 11809535  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
#
#                                                    job_id job_type  \
# 31133     script_job_005543e73a4e5d06e8d2a22f0ff661c5_112    QUERY
# 32183     script_job_005543e73a4e5d06e8d2a22f0ff661c5_112    QUERY
# 32184     script_job_005543e73a4e5d06e8d2a22f0ff661c5_112    QUERY
# 32185     script_job_005543e73a4e5d06e8d2a22f0ff661c5_112    QUERY
# 33244     script_job_005543e73a4e5d06e8d2a22f0ff661c5_112    QUERY
# ...                                                   ...      ...
# 11529509    script_job_26544fc06d7b75330f4690dffeb97d73_3    QUERY
# 11663455  script_job_f00d9d7ba93a273ad25e4208a0c47210_235    QUERY
# 11753533   script_job_fa269c2b1cebb8ef0715c1fbbbeb6a9e_15    QUERY
# 11756626   script_job_74ce260b7c19a0efd09d61a67fb2ddf6_30    QUERY
# 11809535   script_job_b993673a05c37f7a3d98671099f9e4f2_20    QUERY
#
#                   statement_type     priority  \
# 31133     CREATE_TABLE_AS_SELECT  INTERACTIVE
# 32183     CREATE_TABLE_AS_SELECT  INTERACTIVE
# 32184     CREATE_TABLE_AS_SELECT  INTERACTIVE
# 32185     CREATE_TABLE_AS_SELECT  INTERACTIVE
# 33244     CREATE_TABLE_AS_SELECT  INTERACTIVE
# ...                          ...          ...
# 11529509            CREATE_TABLE  INTERACTIVE
# 11663455              DROP_TABLE  INTERACTIVE
# 11753533            CREATE_TABLE  INTERACTIVE
# 11756626            CREATE_TABLE  INTERACTIVE
# 11809535            CREATE_TABLE  INTERACTIVE
#
#                                start_time state  cache_hit reason  \
# 31133    2022-11-17 10:39:35.217000+00:00  DONE      False   None
# 32183    2022-11-17 10:39:35.217000+00:00  DONE      False   None
# 32184    2022-11-17 10:39:35.217000+00:00  DONE      False   None
# 32185    2022-11-17 10:39:35.217000+00:00  DONE      False   None
# 33244    2022-11-17 10:39:35.217000+00:00  DONE      False   None
# ...                                   ...   ...        ...    ...
# 11529509 2022-11-17 10:26:06.011000+00:00  DONE      False   None
# 11663455 2022-11-17 10:57:33.013000+00:00  DONE      False   None
# 11753533 2022-11-17 10:26:12.150000+00:00  DONE      False   None
# 11756626 2022-11-17 10:26:19.404000+00:00  DONE      False   None
# 11809535 2022-11-17 10:26:14.616000+00:00  DONE      False   None
#
#           total_bytes_processed  total_slot_ms   destination_table_id  \
# 31133               16868397047         440314  ric-eu-dl-vc-dev-nprd
# 32183               16868397047         440314  ric-eu-dl-vc-dev-nprd
# 32184               16868397047         440314  ric-eu-dl-vc-dev-nprd
# 32185               16868397047         440314  ric-eu-dl-vc-dev-nprd
# 33244               16868397047         440314  ric-eu-dl-vc-dev-nprd
# ...                         ...            ...                    ...
# 11529509                      0           <NA>  ric-eu-dl-vc-dev-nprd
# 11663455                      0           <NA>  ric-eu-dl-vc-dev-nprd
# 11753533                      0           <NA>  ric-eu-dl-vc-dev-nprd
# 11756626                      0           <NA>  ric-eu-dl-vc-dev-nprd
# 11809535                      0           <NA>  ric-eu-dl-vc-dev-nprd
#
#           total_bytes_billed                         parent_job_id job_status  \
# 31133            16868442112  d8183979-ada6-451f-8e06-77c1ca0da31d   COMPLETE
# 32183            16868442112  d8183979-ada6-451f-8e06-77c1ca0da31d   COMPLETE
# 32184            16868442112  d8183979-ada6-451f-8e06-77c1ca0da31d   COMPLETE
# 32185            16868442112  d8183979-ada6-451f-8e06-77c1ca0da31d   COMPLETE
# 33244            16868442112  d8183979-ada6-451f-8e06-77c1ca0da31d   COMPLETE
# ...                      ...                                   ...        ...
# 11529509                   0  d8183979-ada6-451f-8e06-77c1ca0da31d       None
# 11663455                   0  d8183979-ada6-451f-8e06-77c1ca0da31d       None
# 11753533                   0  d8183979-ada6-451f-8e06-77c1ca0da31d       None
# 11756626                   0  d8183979-ada6-451f-8e06-77c1ca0da31d       None
# 11809535                   0  d8183979-ada6-451f-8e06-77c1ca0da31d       None
#
#                 date
# 31133     2022-11-17
# 32183     2022-11-17
# 32184     2022-11-17
# 32185     2022-11-17
# 33244     2022-11-17
# ...              ...
# 11529509  2022-11-17
# 11663455  2022-11-17
# 11753533  2022-11-17
# 11756626  2022-11-17
# 11809535  2022-11-17
#
# [2653 rows x 18 columns]

# %%
given_day[given_day['job_id'] == 'd8183979-ada6-451f-8e06-77c1ca0da31d']
# Out:
#                            creation_time              project_id  \
# 8073260 2022-11-17 10:26:03.759000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                 user_email  \
# 8073260  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
#
#                                        job_id job_type statement_type  \
# 8073260  d8183979-ada6-451f-8e06-77c1ca0da31d    QUERY         SCRIPT
#
#             priority                       start_time state  cache_hit reason  \
# 8073260  INTERACTIVE 2022-11-17 10:26:03.893000+00:00  DONE       <NA>   None
#
#          total_bytes_processed  total_slot_ms destination_table_id  \
# 8073260          3202324391618      149489264                 None
#
#          total_bytes_billed parent_job_id job_status        date
# 8073260       3202421358592          None       None  2022-11-17

# %%
given_day = given_day.drop_duplicates()

# %%
given_day_no_cache = given_day[given_day['cache_hit'] == False]

# %%
given_day_no_cache.reason.value_counts()
# Out:
# invalidQuery    69
# Name: reason, dtype: int64

# %%
given_day_no_cache = given_day_no_cache[given_day_no_cache['reason'] != 'invalidQuery']

# %%
(given_day_no_cache.total_bytes_billed.sum()*  9.09494702E-13) * 5
# Out:
# 666.1167670959345

# %%
given_day_no_cache
# Out:
# Warning: total number of rows (511672) exceeds max_rows (20000). Falling back to pandas display.
#                             creation_time              project_id  \
# 1377     2022-12-07 07:47:36.459000+00:00  ric-eu-dl-ops-dev-nprd
# 1531     2022-12-07 05:35:36.986000+00:00  ric-eu-dl-ops-dev-nprd
# 2462     2022-12-07 18:49:10.053000+00:00  ric-eu-dl-ops-dev-nprd
# 4241     2022-12-07 05:34:35.292000+00:00  ric-eu-dl-ops-dev-nprd
# 4508     2022-12-07 06:48:30.947000+00:00  ric-eu-dl-ops-dev-nprd
# ...                                   ...                     ...
# 16001260 2022-12-07 16:35:22.671000+00:00  ric-eu-dl-ops-dev-nprd
# 16033927 2022-12-07 14:38:06.709000+00:00  ric-eu-dl-ops-dev-nprd
# 16059554 2022-12-07 16:16:49.447000+00:00  ric-eu-dl-ops-dev-nprd
# 16068025 2022-12-07 15:57:42.794000+00:00  ric-eu-dl-ops-dev-nprd
# 16092629 2022-12-07 15:28:46.382000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                  user_email  \
# 1377      sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 1531      sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 2462      sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 4241      sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 4508      sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# ...                                                     ...
# 16001260  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16033927  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16059554  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16068025  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
# 16092629  sa-gitlab-ci-sbx@ric-eu-dl-ops-dev-nprd.iam.gs...
#
#                                                    job_id job_type  \
# 1377      script_job_7cd9dcc0eaae72e0affe1a171022c33d_115    QUERY
# 1531       script_job_b74597b4d7c6253cdd761b9b12499f62_90    QUERY
# 2462                 763f0608-066f-4fb8-8806-a507ebb79e50    QUERY
# 4241      script_job_dad03eeb3269b72620dd727d99a62f65_108    QUERY
# 4508       script_job_5e6d98cc65115aefc34983096ab15c57_84    QUERY
# ...                                                   ...      ...
# 16001260             4b00dd5d-8ccd-42d8-a847-ffc569fda93f    QUERY
# 16033927             15704eb8-f291-4943-84f5-7eac8cc3fd2f    QUERY
# 16059554             15fefa95-91b2-401c-a609-28423551cd01    QUERY
# 16068025             957c1891-302f-4384-975e-77d521ffd380    QUERY
# 16092629             4e681595-7c80-428c-bebc-7f78c79c4ffd    QUERY
#
#                   statement_type     priority  \
# 1377      CREATE_TABLE_AS_SELECT  INTERACTIVE
# 1531      CREATE_TABLE_AS_SELECT  INTERACTIVE
# 2462      CREATE_TABLE_AS_SELECT  INTERACTIVE
# 4241      CREATE_TABLE_AS_SELECT  INTERACTIVE
# 4508      CREATE_TABLE_AS_SELECT  INTERACTIVE
# ...                          ...          ...
# 16001260                  SELECT  INTERACTIVE
# 16033927                  SELECT  INTERACTIVE
# 16059554                  SELECT  INTERACTIVE
# 16068025                  SELECT  INTERACTIVE
# 16092629                  SELECT  INTERACTIVE
#
#                                start_time state  cache_hit reason  \
# 1377     2022-12-07 07:47:36.609000+00:00  DONE      False   None
# 1531     2022-12-07 05:35:37.146000+00:00  DONE      False   None
# 2462     2022-12-07 18:49:10.154000+00:00  DONE      False   None
# 4241     2022-12-07 05:34:35.551000+00:00  DONE      False   None
# 4508     2022-12-07 06:48:31.073000+00:00  DONE      False   None
# ...                                   ...   ...        ...    ...
# 16001260 2022-12-07 16:35:22.779000+00:00  DONE      False   None
# 16033927 2022-12-07 14:38:06.833000+00:00  DONE      False   None
# 16059554 2022-12-07 16:16:49.577000+00:00  DONE      False   None
# 16068025 2022-12-07 15:57:43.125000+00:00  DONE      False   None
# 16092629 2022-12-07 15:28:46.490000+00:00  DONE      False   None
#
#           total_bytes_processed  total_slot_ms    destination_table_id  \
# 1377                16431124547         609871   ric-eu-dl-vc-dev-nprd
# 1531                15927621909         868596   ric-eu-dl-vc-dev-nprd
# 2462                  227324700          55135   ric-eu-dl-sa-dev-nprd
# 4241                16605073352         598530   ric-eu-dl-vc-dev-nprd
# 4508                16290416353         577792   ric-eu-dl-vc-dev-nprd
# ...                         ...            ...                     ...
# 16001260               20971520          54199  ric-eu-dl-ops-dev-nprd
# 16033927               20971520          43893  ric-eu-dl-ops-dev-nprd
# 16059554               20971520          43282  ric-eu-dl-ops-dev-nprd
# 16068025               20971520          58312  ric-eu-dl-ops-dev-nprd
# 16092629               20971520          45677  ric-eu-dl-ops-dev-nprd
#
#           total_bytes_billed                         parent_job_id job_status  \
# 1377             16431185920  d653609f-edb6-44c5-bf86-97481c83ef57   COMPLETE
# 1531             15927869440  4155a978-e6fe-453c-b2cf-97e9c2c6146f   COMPLETE
# 2462               227540992                                  None   COMPLETE
# 4241             16605249536  d94e5ed0-aa26-492e-87e0-6fdc6af58751   COMPLETE
# 4508             16290676736  c8cc089d-d671-4f71-ab85-867114eedd09   COMPLETE
# ...                      ...                                   ...        ...
# 16001260            31457280                                  None   COMPLETE
# 16033927            31457280                                  None   COMPLETE
# 16059554            31457280                                  None   COMPLETE
# 16068025            31457280                                  None   COMPLETE
# 16092629            31457280                                  None   COMPLETE
#
#                 date
# 1377      2022-12-07
# 1531      2022-12-07
# 2462      2022-12-07
# 4241      2022-12-07
# 4508      2022-12-07
# ...              ...
# 16001260  2022-12-07
# 16033927  2022-12-07
# 16059554  2022-12-07
# 16068025  2022-12-07
# 16092629  2022-12-07
#
# [511672 rows x 18 columns]

# %%
bool_series = pd.isnull(given_day_no_cache["parent_job_id"])

# %%
(given_day_no_cache[bool_series].total_bytes_billed.sum()*  9.09494702E-13) * 5
# Out:
# 413.9302397807744

# %% [markdown]
# # Parent Job Id analysis

# %%
current_job = given_day[given_day['parent_job_id'] == 'c8cc089d-d671-4f71-ab85-867114eedd09']

# %%
current_job.drop_duplicates().total_bytes_billed.sum()
# Out:
# 3211502026752

# %%
given_day[given_day['job_id'] == 'c8cc089d-d671-4f71-ab85-867114eedd09']
# Out:
#                            creation_time              project_id  \
# 2017163 2022-12-07 06:36:11.469000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                 user_email  \
# 2017163  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
#
#                                        job_id job_type statement_type  \
# 2017163  c8cc089d-d671-4f71-ab85-867114eedd09    QUERY         SCRIPT
#
#             priority                       start_time state  cache_hit reason  \
# 2017163  INTERACTIVE 2022-12-07 06:36:11.676000+00:00  DONE       <NA>   None
#
#          total_bytes_processed  total_slot_ms destination_table_id  \
# 2017163          3211397446871      164229162                 None
#
#          total_bytes_billed parent_job_id job_status        date
# 2017163       3211502026752          None       None  2022-12-07

# %%
3023063482368

# %%
3023063482368
# Out:
# 36016298655744

# %% [markdown]
# I would like to check if parent_job_id costs apply if parent id is cached

# %% [markdown]
# # Cached hits

# %%
parent_job_ids = list(given_day.parent_job_id.drop_duplicates())

# %%
given_day[given_day['job_id'].isin(parent_job_ids)]
# Out:
#                             creation_time              project_id  \
# 234181   2022-12-07 05:22:57.577000+00:00  ric-eu-dl-ops-dev-nprd
# 485716   2022-12-07 09:14:12.692000+00:00  ric-eu-dl-ops-dev-nprd
# 540346   2022-12-07 06:32:45.062000+00:00  ric-eu-dl-ops-dev-nprd
# 560325   2022-12-07 04:01:56.018000+00:00  ric-eu-dl-ops-dev-nprd
# 561081   2022-12-07 09:23:44.206000+00:00  ric-eu-dl-ops-dev-nprd
# ...                                   ...                     ...
# 12369986 2022-12-07 04:02:09.492000+00:00  ric-eu-dl-ops-dev-nprd
# 12374097 2022-12-07 04:01:49.513000+00:00  ric-eu-dl-ops-dev-nprd
# 12503173 2022-12-07 04:02:30.830000+00:00  ric-eu-dl-ops-dev-nprd
# 12551950 2022-12-07 04:02:08.140000+00:00  ric-eu-dl-ops-dev-nprd
# 12591831 2022-12-07 04:02:20.361000+00:00  ric-eu-dl-ops-dev-nprd
#
#                                                  user_email  \
# 234181    sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 485716    sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 540346    sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 560325    sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 561081    sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# ...                                                     ...
# 12369986  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 12374097  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 12503173  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 12551950  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
# 12591831  sa-composer-sbx@ric-eu-dl-ops-dev-nprd.iam.gse...
#
#                                         job_id job_type statement_type  \
# 234181    d94e5ed0-aa26-492e-87e0-6fdc6af58751    QUERY         SCRIPT
# 485716    d82b1246-20d6-4833-9341-f45c3078289f    QUERY         SCRIPT
# 540346    24ead3a3-c93d-4181-9a04-48bd06bd1684    QUERY         SCRIPT
# 560325    d2a13fda-3d4a-48dc-8cf1-7d0406397509    QUERY         SCRIPT
# 561081    f7f934df-baec-43b5-b3a0-8a4fda229e0a    QUERY         SCRIPT
# ...                                        ...      ...            ...
# 12369986  a3e0d7e2-c014-4887-b32a-aa2db02c71b7    QUERY         SCRIPT
# 12374097  650b702a-72e2-40be-9dde-3a11c3fc5fc3    QUERY         SCRIPT
# 12503173  5b026f3c-5d69-466c-afb5-8b070cf1d682    QUERY         SCRIPT
# 12551950  ef9d8ee3-2623-4e76-8bfe-07bac92013d3    QUERY         SCRIPT
# 12591831  d9a6daee-f1c5-46e9-ba71-ecd2377317a7    QUERY         SCRIPT
#
#              priority                       start_time state  cache_hit  \
# 234181    INTERACTIVE 2022-12-07 05:22:57.825000+00:00  DONE       <NA>
# 485716    INTERACTIVE 2022-12-07 09:14:12.731000+00:00  DONE       <NA>
# 540346    INTERACTIVE 2022-12-07 06:32:45.111000+00:00  DONE       <NA>
# 560325    INTERACTIVE 2022-12-07 04:01:56.051000+00:00  DONE       <NA>
# 561081    INTERACTIVE 2022-12-07 09:23:44.244000+00:00  DONE       <NA>
# ...               ...                              ...   ...        ...
# 12369986  INTERACTIVE 2022-12-07 04:02:09.533000+00:00  DONE       <NA>
# 12374097  INTERACTIVE 2022-12-07 04:01:49.543000+00:00  DONE       <NA>
# 12503173  INTERACTIVE 2022-12-07 04:02:30.871000+00:00  DONE       <NA>
# 12551950  INTERACTIVE 2022-12-07 04:02:08.183000+00:00  DONE       <NA>
# 12591831  INTERACTIVE 2022-12-07 04:02:20.420000+00:00  DONE       <NA>
#
#          reason  total_bytes_processed  total_slot_ms destination_table_id  \
# 234181     None          3098354844177      142983901                 None
# 485716     None           250107585406      582178236                 None
# 540346     None            31024857952        4785939                 None
# 560325     None               47542208          34074                 None
# 561081     None            10495745528        7660124                 None
# ...         ...                    ...            ...                  ...
# 12369986   None                  11872          26963                 None
# 12374097   None                 651104          25560                 None
# 12503173   None                    552          42549                 None
# 12551950   None                  11872          28473                 None
# 12591831   None                  26136          36259                 None
#
#           total_bytes_billed parent_job_id job_status        date
# 234181         3098447708160          None       None  2022-12-07
# 485716          250108444672          None       None  2022-12-07
# 540346           31026315264          None       None  2022-12-07
# 560325              48234496          None       None  2022-12-07
# 561081           10498342912          None       None  2022-12-07
# ...                      ...           ...        ...         ...
# 12369986            20971520          None       None  2022-12-07
# 12374097            20971520          None       None  2022-12-07
# 12503173            20971520          None       None  2022-12-07
# 12551950            20971520          None       None  2022-12-07
# 12591831            20971520          None       None  2022-12-07
#
# [127 rows x 18 columns]

# %%
parent_job_ids
# Out:
# ['d653609f-edb6-44c5-bf86-97481c83ef57',
#  None,
#  '4155a978-e6fe-453c-b2cf-97e9c2c6146f',
#  'd94e5ed0-aa26-492e-87e0-6fdc6af58751',
#  'c8cc089d-d671-4f71-ab85-867114eedd09',
#  '46ac2a8f-d723-4046-969b-435eb59e0147',
#  '095ba1e9-5a4a-4177-8bf7-8d5dc52873e9',
#  'd8f544bc-17df-4b39-a75d-fb71b811e2d4',
#  '20c49521-e4fd-4567-b575-67e42d7fdee9',
#  'f18a3470-d02e-4d42-b339-4fad82230db0',
#  '6a94028e-957d-49ef-b382-d9017beb897b',
#  '2edabfff-f13b-4767-b9b0-d624418f3e17',
#  'e19017d5-ccd5-429c-bb70-5d8990b88533',
#  'f6e193f1-52e9-4a20-ac92-0e2fba89f34d',
#  '43f3af2f-7d9e-46cb-aae9-338bade12780',
#  'cc5f8f98-60a5-460c-9c93-810de54f904e',
#  'e106c11a-8ffe-469b-8601-5b20f5f13f07',
#  '273ee58c-a468-45cf-ad94-882183f354f9',
#  '65e7126a-6d5b-4338-be6a-7145fd04d287',
#  'bbe65ffa-d794-4a32-8cbb-5596b21dd40a',
#  '77481c71-19fb-4247-947f-671e7ba3d6f3',
#  'eaaee96e-bda5-4303-86c8-0beefb2183c7',
#  'f61a6dbb-5d33-442a-b94a-663cd1359791',
#  'd56df1a1-ed47-4c37-ba76-dc588ec1ab01',
#  'f2f4ea12-fb7a-4e5e-b33f-8e60e8b28aed',
#  'b75b53a7-91ed-4100-beba-6e9298d259a5',
#  '9d1ae3dc-26d6-4eaf-a623-4740eecff6d9',
#  '9e501842-f188-4cce-a277-b694b5c8b6b1',
#  '24ead3a3-c93d-4181-9a04-48bd06bd1684',
#  'a196df18-9965-4a38-9436-aacddc6ec7c5',
#  '2801587e-35f8-41b2-bd42-d367bb119285',
#  'd2a13fda-3d4a-48dc-8cf1-7d0406397509',
#  'c1530d89-0def-43a2-8c10-0d875a14fa94',
#  '191a203a-2ea3-43fd-be24-776d8b1d8b5e',
#  'f7f934df-baec-43b5-b3a0-8a4fda229e0a',
#  '75014cb0-8c96-4c01-9b74-21d3db56649c',
#  'dda41325-650b-4dc9-b597-f3a19a5b80f9',
#  'ad74a284-99df-4832-b508-66bdf6416060',
#  '7ca6183a-075e-4e48-acf4-f2e00d9238f6',
#  'd82b1246-20d6-4833-9341-f45c3078289f',
#  '690676d1-a27c-4a08-bb3e-2ae0df08224a',
#  '6c5b1914-2352-48cf-82c8-ccb04e1efd42',
#  'ecc3f61b-bd18-423d-b2e7-24e8fb118b5f',
#  '08b1904d-07bc-4b54-9212-f972e37b84c3',
#  '7f036e20-e03a-4a3d-9c90-4cb1c11ba889',
#  '3cf52e4d-181b-4b22-9254-3125db1eff51',
#  '9c3b2e2b-05c2-47eb-9d63-c8bf6039b3dd',
#  '543341af-2227-42bd-ab1a-33e1fbd903a1',
#  '604412d1-c134-4fc0-868e-2e55613e6cdc',
#  '383a89d8-61a3-4fd7-a1d7-f5657d207849',
#  '8a9a29bb-961d-46cc-9a87-9c9db3a00ea6',
#  '041a9d75-742c-4ea0-a43d-18bdd35c09d6',
#  '0e254c4f-f018-4230-82e9-b13c8fffae2f',
#  'a3405860-3d52-489b-9bff-af448e0d6f6c',
#  '6818ca47-cb2d-4789-82d7-afbbbb054b9c',
#  '117f13e6-2277-4f68-b271-b19f00d3fb01',
#  'b23065e6-bda4-47d8-9c37-c78110889f5d',
#  'df5fe5c2-50cf-481a-bf21-002f03e5aa04',
#  '3b4ce2ff-4c74-4a58-9c0a-b16af67f0f96',
#  '822e9e13-242b-4545-8054-9edc47070e8d',
#  '7b4054d6-d715-460b-aa98-0f38b070124e',
#  '1b62fb35-4f65-4b16-a22c-60f147acfc84',
#  '28402675-1aa8-410c-a4ae-ac2e6a82cefc',
#  'cf48249e-ce46-4cea-9f4d-32d852dc7672',
#  '265c39de-39e6-40a3-bc71-ada0dc2d8968',
#  '7748135c-32db-4e11-8499-08faa4bb06ab',
#  'bec42a48-6bce-4752-9c15-bdc4c36b72e2',
#  'bqjob_r7c117d9fb8219a8c_00000184ec1b9078_1',
#  '545f8958-dffc-423a-9ef4-aa7bbd3664fa',
#  'fcd07a9e-42dc-430f-b69a-7997727db72a',
#  '776aa7a3-29a7-48e3-ae36-bc2ef345f4b1',
#  'fa0ec7ba-60ef-47ee-a529-c51a9a9071e1',
#  'c46045f9-a689-49b0-91e4-c177f1b4b3dc',
#  '1640ba04-4a6c-4c17-8989-2e0271984703',
#  '64854635-9115-46bf-8e7c-10d86c2b4605',
#  'a66b25da-fbbb-4acf-820b-83d42a7faa57',
#  '5b026f3c-5d69-466c-afb5-8b070cf1d682',
#  '4bffa218-a238-45e1-95b1-4377801f3016',
#  '0d45373f-3f8a-46b1-80fa-33f538de5385',
#  '95b0fdf3-c5e2-4655-99bf-ce1ead4a0347',
#  '1a5a617d-27b9-4ec7-99ba-9d9dd779ca6c',
#  '44ea3289-eb31-4d5c-a23f-468f771ca899',
#  '0e8ee531-a5aa-45dc-850f-cc13f2ac0ede',
#  '2a003aa1-f5f5-45d6-a588-7f20b61f2653',
#  '6ab0435b-8934-499f-8ad3-a19cc8f3f72c',
#  'c96ed2a9-1f40-4e48-a6fd-33491a569873',
#  '829bf8a9-ff25-444f-ad7f-bd6310214703',
#  '4e1f658f-54a4-4eb6-8169-a6cfcc489159',
#  '5eca6460-de97-4abe-a29c-13c9e2ef6379',
#  'bqjob_r242d333166ae8a76_00000184ec22aae8_1',
#  'c624ef04-9c04-4f2d-b53d-e14e919ad00b',
#  '35c31787-8906-4dcd-9950-9015981f1b7b',
#  'a2a9e485-f679-4e35-95de-36d1f6be99b8',
#  'eeea2de0-4da3-410c-89d8-bb40eb2d3551',
#  '4c882123-9f83-4e08-b953-c2f17cbe0cc0',
#  'bqjob_r5c9373a392814ba3_00000184ec20afce_1',
#  'bqjob_r28174a23171ad2dd_00000184ec21c710_1',
#  'df279918-3530-4cdd-aa54-d58ff93bf769',
#  '7efbac5d-352e-4b6f-b14a-fed97145e249',
#  'cdd9a9ef-a5b8-43e1-8f40-27de97458a36',
#  '93561878-4471-471b-bc82-444e9988267f',
#  '730f01fa-7434-4ab2-abbb-091c5047e300',
#  '30734020-1532-4327-b9ff-6a6c6393882f',
#  '841ee97b-be17-45a0-9c4f-ea420eb35eab',
#  '92e0aef7-c1d4-45fb-b67b-b495fd947078',
#  '8f523ac5-9f59-4439-aa8a-63575b3fc9a1',
#  'e08b841d-f69a-46f9-9702-81c0d5e0c8fb',
#  'b774f6f9-24f6-418b-bc40-2c2ca44b9b6e',
#  'd9a6daee-f1c5-46e9-ba71-ecd2377317a7',
#  'b397159d-1be8-4e26-b718-cd4d60cb57b4',
#  '15fac00d-de08-4c6d-8622-303f2197d04d',
#  '880e3544-0a4f-4230-9484-18ad125f323b',
#  '650b702a-72e2-40be-9dde-3a11c3fc5fc3',
#  'c87c9272-1d45-4550-a9b7-2e982a18659d',
#  'cf155f4b-6aae-4074-b8a5-ec90eb197984',
#  '0392904c-efe7-4ca3-b633-03487c374f91',
#  'bbf886eb-00fb-4fec-99c0-9a9bc3f00e5c',
#  'ef9d8ee3-2623-4e76-8bfe-07bac92013d3',
#  '29e2de7a-1d67-460f-9da8-442e66d5a76f',
#  'bqjob_r6fb9c132c425d5af_00000184ec1fbb4e_1',
#  '472caef8-1516-44f5-a9e5-28c48615ec43',
#  'e48a1928-a336-4394-8a4c-37578eec04e0',
#  '04b241b7-e3ec-4338-a3e0-c9e7f620c740',
#  'e1afce4b-80a4-442b-8789-0907e34e7056',
#  'a3e0d7e2-c014-4887-b32a-aa2db02c71b7',
#  'b883a493-4a68-4354-89b2-f17d292d49e3',
#  '9a5ef81a-f8d2-407c-ad1d-f5846423f388',
#  '066af720-a607-4ed5-8881-cf897eb95122']
